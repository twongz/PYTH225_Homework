# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
bling = pd.read_csv('diamonds.csv')
diamonds = bling.copy()

# %%
df = bling.copy()

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.rename(columns={'x' : 'width', 'y' : 'height', 'z' : 'depth'})
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price  width  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326   3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326   3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327   4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334   4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335   4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...    ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757   5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757   5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757   5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757   6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757   5.83
#
#        height  depth
# ...

# %%
sns.countplot(x="clarity", data=diamonds, hue='cut');

# %%
diamonds.cut.value_counts().plot(kind='pie', figsize=(8,8));

# %%
IF = diamonds[diamonds.clarity == 'IF']

# %% [markdown]
# Breakdown of the IF and I1 diamonds
# Creat

# %%
diamonds.clarity.value_counts(ascending=False)
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
sns.set(style="white")

# %%
sns.relplot(x="price", y="color", hue="carat", size="carat",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=bling);
